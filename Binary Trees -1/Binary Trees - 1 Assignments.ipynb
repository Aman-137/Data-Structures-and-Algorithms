# %%
# Sum of Nodes.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None




def getSum(root):
	#Your code goes here
    if root == None:
        return 0
    
    leftSum = getSum(root.left)
    rightSum = getSum(root.right)

    
    return root.data + leftSum + rightSum










#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
print(getSum(root))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fa22627a1195> in <module>
#      73
#      74 # Main
# ---> 75 root = takeInput()
#      76 print(getSum(root))
#
# <ipython-input-1-fa22627a1195> in takeInput()
#      40 #Taking level-order input using fast I/O method
#      41 def takeInput():
# ---> 42     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      43     start = 0
#      44
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Preorder Binary Tree.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def preOrder(root):
	#Your code goes here
    if root == None:
        return
    
    print(root.data, end = " ")
    preOrder(root.left)
    preOrder(root.right)
    return



	



#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
preOrder(root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-2b494d4bbeae> in <module>
#      68
#      69 # Main
# ---> 70 root = takeInput()
#      71 preOrder(root)
#
# <ipython-input-2-2b494d4bbeae> in takeInput()
#      35 #Taking level-order input using fast I/O method
#      36 def takeInput():
# ---> 37     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      38     start = 0
#      39
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# PostOrder Binary Tree.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)

#Following the structure used for Binary Tree
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def postOrder(root):
	#Your code goes here
    if root == None:
        return
    
    postOrder(root.left)
    postOrder(root.right)
    print(root.data, end = " ")
    return



	


#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
postOrder(root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d0d509c7095a> in <module>
#      67
#      68 # Main
# ---> 69 root = takeInput()
#      70 postOrder(root)
#
# <ipython-input-4-d0d509c7095a> in takeInput()
#      34 #Taking level-order input using fast I/O method
#      35 def takeInput():
# ---> 36     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      37     start = 0
#      38
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Nodes Greater than X.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def countNodesGreaterThanX(root, x) :
    if root == None:
        return 0
    if root.data>x:
        return 1 + countNodesGreaterThanX(root.left, x) + countNodesGreaterThanX(root.right, x)
    else:
        return 0 + countNodesGreaterThanX(root.left, x) + countNodesGreaterThanX(root.right, x)





#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0

    length = len(levelOrder)

    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()
x = int(stdin.readline().strip())

count = countNodesGreaterThanX(root, x)
print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-dc64969d782e> in <module>
#      65
#      66 # Main
# ---> 67 root = takeInput()
#      68 x = int(stdin.readline().strip())
#      69
#
# <ipython-input-5-dc64969d782e> in takeInput()
#      32 #Taking level-order input using fast I/O method
#      33 def takeInput():
# ---> 34     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      35     start = 0
#      36
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Height of Tree.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def height(root) :
	#Your code goes here
    if root == None:
        return 0
    
    leftHeight = height(root.left)
    rightHeight = height(root.right)
    
    if leftHeight > rightHeight:
        return 1 + leftHeight
    
    else:
        return 1 + rightHeight







#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

# Main
root = takeInput()

h = height(root)
print(h)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c378ea367493> in <module>
#      76
#      77 # Main
# ---> 78 root = takeInput()
#      79
#      80 h = height(root)
#
# <ipython-input-6-c378ea367493> in takeInput()
#      40 #Taking level-order input using fast I/O method
#      41 def takeInput():
# ---> 42     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      43     start = 0
#      44
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Replace Node with Depth.



from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None




def changeToDepthTree(root, level=0) :
	#Your code goes here
    if root == None:
        return
    
    root.data = level
    
    changeToDepthTree(root.left, level+1)
    changeToDepthTree(root.right, level+1)
    





#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root


def inOrder(root) :
	if root is None :
		return 

	inOrder(root.left)
	print(root.data, end = " ")
	inOrder(root.right)
	

# Main
root = takeInput()

changeToDepthTree(root)
inOrder(root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-74018eeef1aa> in <module>
#      82
#      83 # Main
# ---> 84 root = takeInput()
#      85
#      86 changeToDepthTree(root)
#
# <ipython-input-7-74018eeef1aa> in takeInput()
#      36 #Taking level-order input using fast I/O method
#      37 def takeInput():
# ---> 38     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      39     start = 0
#      40
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Is Node Present?




from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None




def isNodePresent(root, x) :
	#Your code goes here
    if root == None:
        return False
    
    if root.data == x:
        return True
    
    leftNode = isNodePresent(root.left, x)
    
    if leftNode:
        return True
    
    rightNode = isNodePresent(root.right, x)
    
    return rightNode




#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

	

# Main
root = takeInput()
x = int(stdin.readline().strip())

if isNodePresent(root, x) :
	print("true")

else :
	print("false")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-013bcd186dd5> in <module>
#      80
#      81 # Main
# ---> 82 root = takeInput()
#      83 x = int(stdin.readline().strip())
#      84
#
# <ipython-input-9-013bcd186dd5> in takeInput()
#      42 #Taking level-order input using fast I/O method
#      43 def takeInput():
# ---> 44     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      45     start = 0
#      46
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Print Nodes without Siblings.




from sys import stdin, setrecursionlimit
import queue

setrecursionlimit(10 ** 6)


#Following is the structure used to represent the Binary Tree Node
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None



def printNodesWithoutSibling(root) :
	# Your code goes here
    if root == None:
        return
    
    if root.left != None and root.right != None:
        printNodesWithoutSibling(root.left)
        printNodesWithoutSibling(root.right)
        
        
    elif root.right != None:
        print(root.right.data, end=" ")
        printNodesWithoutSibling(root.right)
        
    
    elif root.left != None:
        print(root.left.data, end=" ")
        printNodesWithoutSibling(root.left)



	



#Taking level-order input using fast I/O method
def takeInput():
    levelOrder = list(map(int, stdin.readline().strip().split(" ")))
    start = 0
    
    length = len(levelOrder)

    if length == 1 :
        return None
    
    root = BinaryTreeNode(levelOrder[start])
    start += 1

    q = queue.Queue()
    q.put(root)

    while not q.empty():
        currentNode = q.get()

        leftChild = levelOrder[start]
        start += 1

        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)

        rightChild = levelOrder[start]
        start += 1

        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)

    return root

	

# Main
root = takeInput()
printNodesWithoutSibling(root)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-e30e6f120ddd> in <module>
#      84
#      85 # Main
# ---> 86 root = takeInput()
#      87 printNodesWithoutSibling(root)
#
# <ipython-input-10-e30e6f120ddd> in takeInput()
#      46 #Taking level-order input using fast I/O method
#      47 def takeInput():
# ---> 48     levelOrder = list(map(int, stdin.readline().strip().split(" ")))
#      49     start = 0
#      50
#
# ValueError: invalid literal for int() with base 10: ''
