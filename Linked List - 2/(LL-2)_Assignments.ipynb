# %%
# Find Node of LL (Recursively).



from sys import stdin, setrecursionlimit
setrecursionlimit(10 ** 6)

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None


def findNodeRec(head, n) :
	#Your code goes here
    if head is  None:
        return -1

    if head.data == n:
        return 0
    
    smallHead = findNodeRec(head.next, n)
    
    if smallHead is not -1:
        return (1 + smallHead)
    
    else:
        return -1







def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head




def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :
    
    head = takeInput()
    n = int(stdin.readline().rstrip())    

    print(findNodeRec(head, n))

    t -= 1
# Out:
# <>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-1-458698d30350>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if smallHead is not -1:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-458698d30350> in <module>
#      67
#      68 #main
# ---> 69 t = int(stdin.readline().rstrip())
#      70
#      71 while t > 0 :
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Even after Odd Linked list.



from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None


def evenAfterOdd(head) :
    #Your code goes here
    
    if head is None:
        return
    
    eH=None
    eT=None
    oH=None
    oT=None
    while head:
        if head.data%2==0:
            if eH is None:
                eH=head
                eT=head
                head=head.next
            else:
                eT.next=head
                eT=eT.next
                head=head.next
        else:
            if oH is None:
                oH=head
                oT=head
                head=head.next
            else:
                oT.next=head
                oT=oT.next
                head=head.next
    if oH is None:
        eT.next=None
        return eH
    if eH is None:
        oT.next=None
        return oH
    eT.next=None
    #oT.next=None
    oT.next=eH
    return oH






#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :
    
    head = takeInput()
    newHead = evenAfterOdd(head)
    printLinkedList(newHead)  
    
    t -= 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4c9569894b25> in <module>
#      89
#      90 #main
# ---> 91 t = int(stdin.readline().rstrip())
#      92
#      93 while t > 0 :
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Swap two Nodes of Linked List.



from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None



def swapNodes(head, i, j) :
	#Your code goes her
    if i == j:
        return head
    
    currNode = head
    prev = None
    
    firstNode = None
    secNode = None
    firstNodePrev = None
    secNodePrev = None
    
    pos = 0
    
    while currNode is not None:
        
        if pos == i:
            firstNodePrev = prev
            firstNode = currNode
            
        elif pos == j:
            secNodePrev = prev
            secNode = currNode
            
        prev = currNode
        currNode = currNode.next
        
        pos += 1
        
    if firstNodePrev is not None:
        firstNodePrev.next = secNode
        
    else:
        head = secNode
    
    if secNodePrev is not None:
        secNodePrev.next = firstNode
        
    else:
        head = firstNode
        
    currfirstNode = secNode.next
    secNode.next = firstNode.next
    firstNode.next = currfirstNode
    
    return head








#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head




def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :
    
    head = takeInput()
    i_j = stdin.readline().strip().split(" ")

    i = int(i_j[0])
    j = int(i_j[1])

    newHead = swapNodes(head, i, j)
    printLinkedList(newHead)

    t -= 1

# %%
# K-reverse.



from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None



def kReverse(head, k):
    
    if k== 0 or k == 1:
        return head
    #if head is None:
     #   return
    curr = head
    next = None
    prev = None
    count = 0
    while curr is not None and count < k:
        next = curr.next
        curr.next = prev
        prev = curr
        curr = next
#        curr = curr.next
        count += 1

    if next is not None:
        head.next = kReverse(next, k)
        
        
    return prev
        
    # return prev

    #smallAns = kReverse(curr.next, k)
    #curr.next = None
    #newHead = reverseLL(head)
    #head.next = smallAns
    #return newHead







#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head




def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :
    
    head = takeInput()
    k = int(stdin.readline().strip())

    newHead = kReverse(head, k)
    printLinkedList(newHead)

    t -= 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a1f6e837402c> in <module>
#      88
#      89 #main
# ---> 90 t = int(stdin.readline().rstrip())
#      91
#      92 while t > 0 :
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Using Bubble Sort sort the Linked list (iteratively).



from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None



def bubbleSort(head) :
	#Your code goes here
    swap = 0
    
    if head != None:
        
        while (1):
            
            swap = 0
            curr = head
            while (curr.next != None):
                
                if curr.data > curr.next.data:
                    
                    swap += 1
                    p = curr.data
                    curr.data = curr.next.data
                    curr.next.data = p
                    curr = curr.next
                else:
                    curr = curr.next
                    
            if swap == 0:
                break
            else:
                continue
                
        return head
    
    else:
        return head








def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
head = takeInput()
head = bubbleSort(head)
printLinkedList(head)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e20c9f4c5c8e> in <module>
#      87
#      88 #main
# ---> 89 head = takeInput()
#      90 head = bubbleSort(head)
#      91 printLinkedList(head)
#
# <ipython-input-5-e20c9f4c5c8e> in takeInput()
#      56     tail = None
#      57
# ---> 58     datas = list(map(int, stdin.readline().rstrip().split(" ")))
#      59
#      60     i = 0
#
# ValueError: invalid literal for int() with base 10: ''
